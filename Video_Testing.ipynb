# %%
from ultralytics import YOLO

# %%
model = YOLO('results/runs/detect/train2/weights/best.pt')
model.predict(source="VN20241022_004114.mp4",save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/931) E:\major\Traffic SIGNAL\data\Original\tt2\VN20241022_004114.mp4: 384x640 1 stop, 187.5ms
# video 1/1 (frame 2/931) E:\major\Traffic SIGNAL\data\Original\tt2\VN20241022_004114.mp4: 384x640 1 stop, 124.7ms
# video 1/1 (frame 3/931) E:\major\Traffic SIGNAL\data\Original\tt2\VN20241022_004114.mp4: 384x640 2 stops, 116.7ms
# ...
